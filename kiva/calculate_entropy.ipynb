# %%
# Out:
# Running cells with 'Python 2.7.18 64-bit ('2.7.18')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/farastu/.pyenv/versions/2.7.18/bin/python -m pip install ipykernel -U --force-reinstall'
